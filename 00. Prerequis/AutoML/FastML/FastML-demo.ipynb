# %% [markdown]
# # Requirements for fastml

# %%
# !pip install fast-ml
# Out:
# Collecting fast-ml
#   Downloading fast_ml-3.68-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: fast-ml
# Successfully installed fast-ml-3.68

# %%
from fast_ml.utilities import reduce_memory_usage, display_all
from fast_ml.missing_data_imputation import MissingDataImputer_Numerical,MissingDataImputer_Categorical,display
from fast_ml.missing_data_analysis import MissingDataAnalysis
from fast_ml import eda
from fast_ml.outlier_treatment import OutlierTreatment
from fast_ml.feature_engineering import FeatureEngineering_Numerical,FeatureEngineering_Categorical

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = sns.load_dataset("iris")

# %%
display_all(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 12            4.8          3.0           1.4          0.1      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 16            5.4          3.9           1.3          0.4      setosa
# 17            5.1          3.5           1.4          0.3      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 19            5.1          3.8           1.5          0.3      setosa
# 20            5.4          3.4           1.7          0.2      setosa
# 21            5.1          3.7           1.5          0.4      setosa
# 22            4.6          3.6           1.0          0.2      setosa
# 23            5.1          3.3           1.7          0.5      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 25            5.0          3.0           1.6          0.2      setosa
# 26            5.0          3.4           1.6          0.4      setosa
# 27            5.2          3.5           1.5          0.2      setosa
# 28            5.2          3.4           1.4          0.2      setosa
# 29            4.7          3.2           1.6          0.2      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 31            5.4          3.4           1.5          0.4      setosa
# 32            5.2          4.1           1.5          0.1      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# 34            4.9          3.1           1.5          0.2      setosa
# 35            5.0          3.2           1.2          0.2      setosa
# 36            5.5          3.5           1.3          0.2      setosa
# 37            4.9          3.6           1.4          0.1      setosa
# 38            4.4          3.0           1.3          0.2      setosa
# 39            5.1          3.4           1.5          0.2      setosa
# 40            5.0          3.5           1.3          0.3      setosa
# 41            4.5          2.3           1.3          0.3      setosa
# 42            4.4          3.2           1.3          0.2      setosa
# 43            5.0          3.5           1.6          0.6      setosa
# 44            5.1          3.8           1.9          0.4      setosa
# 45            4.8          3.0           1.4          0.3      setosa
# 46            5.1          3.8           1.6          0.2      setosa
# 47            4.6          3.2           1.4          0.2      setosa
# 48            5.3          3.7           1.5          0.2      setosa
# 49            5.0          3.3           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# 57            4.9          2.4           3.3          1.0  versicolor
# 58            6.6          2.9           4.6          1.3  versicolor
# 59            5.2          2.7           3.9          1.4  versicolor
# 60            5.0          2.0           3.5          1.0  versicolor
# 61            5.9          3.0           4.2          1.5  versicolor
# 62            6.0          2.2           4.0          1.0  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 64            5.6          2.9           3.6          1.3  versicolor
# 65            6.7          3.1           4.4          1.4  versicolor
# 66            5.6          3.0           4.5          1.5  versicolor
# 67            5.8          2.7           4.1          1.0  versicolor
# 68            6.2          2.2           4.5          1.5  versicolor
# 69            5.6          2.5           3.9          1.1  versicolor
# 70            5.9          3.2           4.8          1.8  versicolor
# 71            6.1          2.8           4.0          1.3  versicolor
# 72            6.3          2.5           4.9          1.5  versicolor
# 73            6.1          2.8           4.7          1.2  versicolor
# 74            6.4          2.9           4.3          1.3  versicolor
# 75            6.6          3.0           4.4          1.4  versicolor
# 76            6.8          2.8           4.8          1.4  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 78            6.0          2.9           4.5          1.5  versicolor
# 79            5.7          2.6           3.5          1.0  versicolor
# 80            5.5          2.4           3.8          1.1  versicolor
# 81            5.5          2.4           3.7          1.0  versicolor
# 82            5.8          2.7           3.9          1.2  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# 84            5.4          3.0           4.5          1.5  versicolor
# 85            6.0          3.4           4.5          1.6  versicolor
# 86            6.7          3.1           4.7          1.5  versicolor
# 87            6.3          2.3           4.4          1.3  versicolor
# 88            5.6          3.0           4.1          1.3  versicolor
# 89            5.5          2.5           4.0          1.3  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 91            6.1          3.0           4.6          1.4  versicolor
# 92            5.8          2.6           4.0          1.2  versicolor
# 93            5.0          2.3           3.3          1.0  versicolor
# 94            5.6          2.7           4.2          1.3  versicolor
# 95            5.7          3.0           4.2          1.2  versicolor
# 96            5.7          2.9           4.2          1.3  versicolor
# 97            6.2          2.9           4.3          1.3  versicolor
# 98            5.1          2.5           3.0          1.1  versicolor
# 99            5.7          2.8           4.1          1.3  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# 102           7.1          3.0           5.9          2.1   virginica
# 103           6.3          2.9           5.6          1.8   virginica
# 104           6.5          3.0           5.8          2.2   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 106           4.9          2.5           4.5          1.7   virginica
# 107           7.3          2.9           6.3          1.8   virginica
# 108           6.7          2.5           5.8          1.8   virginica
# 109           7.2          3.6           6.1          2.5   virginica
# 110           6.5          3.2           5.1          2.0   virginica
# 111           6.4          2.7           5.3          1.9   virginica
# 112           6.8          3.0           5.5          2.1   virginica
# 113           5.7          2.5           5.0          2.0   virginica
ginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Categorical plots for an specified column

# %%
variables = df.loc[:,["sepal_length","sepal_width","petal_length","petal_width"]]

# %% [markdown]
# # Data Information

# %%
eda.df_info(df)
# Out:
#              data_type data_type_grp num_unique_values  \
# sepal_length   float16     Numerical                35
# sepal_width    float16     Numerical                23
# petal_length   float16     Numerical                43
# petal_width    float16     Numerical                22
# species       category      category                 3
#
#                                            sample_unique_values num_missing  \
# sepal_length  [5.1015625, 4.8984375, 4.69921875, 4.6015625, ...           0
# sepal_width   [3.5, 3.0, 3.19921875, 3.099609375, 3.59960937...           0
# petal_length  [1.400390625, 1.2998046875, 1.5, 1.7001953125,...           0
# petal_width   [0.199951171875, 0.39990234375, 0.300048828125...           0
# species                         [setosa, versicolor, virginica]           0
#
#              perc_missing
# sepal_length          0.0
# sepal_width           0.0
# petal_length          0.0
# petal_width           0.0
# species               0.0

# %%
eda.numerical_describe(df,["sepal_length","sepal_width","petal_length","petal_width"])
# Out:
#               count      mean       std        0%       10%       20%  \
# sepal_length  150.0  5.843750  0.828125  4.300781  4.800781  5.000000
# sepal_width   150.0  3.056641  0.435791  2.000000  2.500000  2.699219
# petal_length  150.0  3.755859  1.764648  1.000000  1.400391  1.500000
# petal_width   150.0  1.199219  0.762207  0.099976  0.199951  0.199951
#
#                    30%       40%       50%       60%       70%       80%  \
# sepal_length  5.270312  5.601562  5.800781  6.101562  6.300781  6.520313
# sepal_width   2.800781  3.000000  3.000000  3.099609  3.199219  3.400391
# petal_length  1.700195  3.900391  4.349609  4.640625  5.000000  5.320312
# petal_width   0.399902  1.159961  1.299805  1.500000  1.799805  1.900391
#
#                    90%       95%      100%
# sepal_length  6.898438  7.255078  7.898438
# sepal_width   3.609570  3.800781  4.398438
# petal_length  5.800781  6.101562  6.898438
# petal_width   2.199219  2.300781  2.500000

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # Exploratory data analysis

# %%
eda.numerical_variable_detail(df,variable="sepal_length")
# Out:
# Total Number of observations :  150
#
# Datatype : float16
#
# Number of distinct values : 35
# **<u>5 Point Summary :</u>**
#   Minimum  :		 4.3
#   25th Percentile :	 5.1015625
#   Median :		 5.8
#   75th Percentile :	 6.3984375
#   Maximum  :		 7.9
# **<u>Missing Values :</u>**
#   Number : 0
#   Percentage : 0.0 %
# **<u>Variable distribution and Spread statistics :</u>**
# Skewness : 0.3127
# Kurtosis : -0.5527
# **<u>Normality Check :</u>**
# **<u>Box Plot and Visual check for Outlier  :</u>**
# **<u>Outliers (using IQR):</u>**
#   Right end outliers : 0
#   Left end outliers : 0
# **<u>Bivariate plots: Relationship with Target Variable:</u>**
# **<u>Explore various transformations for sepal_length</u>**
# 1. Logarithmic Transformation
# 2. Exponential Transformation
# 3. Square Transformation
# 4. Square-root Transformation
# 5. Box-Cox Transformation
# Optimal Lambda for Box-Cox transformation is : -18.944271593086487
#
# 6. Yeo Johnson Transformation
# Optimal Lambda for Yeo Johnson transformation is : -0.3192814350679965

# %%
eda.numerical_plots(df,["sepal_length","sepal_width","petal_length","petal_width"],normality_check=True)
# Out:
# **1. Plot for sepal_length**
# **2. Plot for sepal_width**
# **3. Plot for petal_length**
# **4. Plot for petal_width**

# %%
eda.numerical_plots_with_target(df,["sepal_length","sepal_width","petal_length","petal_width"],"species",model_type="clf")
# Out:
# **1. Plot for sepal_length**
# **2. Plot for sepal_width**
# **3. Plot for petal_length**
# **4. Plot for petal_width**

# %%
eda.numerical_check_outliers(df,["sepal_length","sepal_width","petal_length","petal_width"])
# Out:
#               lower_bound_outliers  upper_bound_outliers  total_outliers  \
# sepal_width                      1                     3               4
# sepal_length                     0                     0               0
# petal_length                     0                     0               0
# petal_width                      0                     0               0
#
#               perc_outliers
# sepal_width        2.666667
# sepal_length       0.000000
# petal_length       0.000000
# petal_width        0.000000

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # Missing Data Imputation for an numerical columns and its methods

# %%
df1 = sns.load_dataset("titanic")
df1.shape
# Out:
# (891, 15)

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
ms = MissingDataImputer_Numerical(method="median")

# %%
imputer = ms.fit(df1,["age"])

# %%
df1 = imputer.transform(df1)

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# age_nan          0
# dtype: int64

# %%
cat_imputer = MissingDataImputer_Categorical(method = 'custom_value')
cat_imputer.fit(df1,["embark_town"])
df2 = cat_imputer.transform(df1)

# %%
ms1 = MissingDataImputer_Categorical(method='frequent')
ms2 = ms1.fit(df1,["deck"])
ms1.transform(df1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  age_nan  \
# 0      man        True    C  Southampton    no  False        0
# 1    woman       False    C    Cherbourg   yes  False        0
# 2    woman       False    C  Southampton   yes   True        0
# 3    woman       False    C  Southampton   yes  False        0
# 4      man        True    C  Southampton    no   True        0
# ..     ...         ...  ...          ...   ...    ...      ...
# 886    man        True    C  Southampton    no   True        0
# 887  woman       False    B  Southampton   yes   True        0
# 888  woman       False    C  Southampton    no  False        1
# 889    man        True    C    Cherbourg   yes   True        0
# 890    man        True    C   Queenstown    no   True        0
#
#      embark_town_nan  deck_nan
# 0                  0         1
# 1                  0         0
# 2                  0         1
# 3                  0         0
# 4                  0         1
# ..               ...       ...
# 886                0         1
# 887                0         0
# 888                0         1
# 889                0         0
# 890                0         1
#
# [891 rows x 18 columns]

# %% [markdown]
# # Outlier treatment by IQR

# %%
plt.figure(figsize=(15,5))
df1.boxplot(column="age")
# Out:
# <Axes: >

# %%
ot = OutlierTreatment(method="gaussian")

# %%
os = ot.fit(df1,variables=["age"])

# %%
df2 = os.transform(df1)

# %%
plt.figure(figsize=(15,5))
df2.boxplot(column="age")
# Out:
# <Axes: >

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_nan  embark_town_nan  \
# 0    man        True    C  Southampton    no  False        0                0
# 1  woman       False    C    Cherbourg   yes  False        0                0
# 2  woman       False    C  Southampton   yes   True        0                0
# 3  woman       False    C  Southampton   yes  False        0                0
# 4    man        True    C  Southampton    no   True        0                0
#
#    deck_nan
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
