# %% [markdown]
# # Automatisation de l'EDA avec Autoplotter

# %% [markdown]
# ###**Automatisez votre flux de travail de traitement de texte en une seule ligne de code Python**

# %% [markdown]
# + Le traitement du langage naturel (NLP) est un sous-domaine de l'IA impliquant des interactions entre l'ordinateur et le langage naturel. Il s'agit de former un modèle de science des données capable de comprendre et de mettre en œuvre l'utilisation des tâches en langage naturel. Un projet NLP typique suit divers aspects du pipeline pour former un modèle. Les différentes étapes du pipeline incluent le nettoyage du texte, la tokenisation, le stemming, l'encodage en vecteur numérique, etc., suivis d'une formation de modèle.
#
# + L'ensemble de données dérivé pour les tâches NLP est constitué de données textuelles, principalement dérivées d'Internet. La plupart du temps, les données textuelles utilisées pour la modélisation NLP sont sales et doivent être nettoyées au début du traitement des données. Un scientifique des données passe la plupart du temps dans le prétraitement des données, ce qui inclut le nettoyage des données textuelles.
#
# + CleanText, facilite le processus de nettoyage des données textuelles et accélère le pipeline de prétraitement des données.

# %% [markdown]
# + https://towardsdatascience.com/4-nlp-libraries-for-automatic-language-identification-of-text-data-in-python-cbc6bf664774
# + https://github.com/koaning/bulk
# + https://github.com/practical-nlp/practical-nlp-code/tree/master/Ch2

# %% [markdown]
# ###**Qu'est-ce que Clean Text ?**
#
#
# + **CleanText** est une bibliothèque Python open source qui permet de nettoyer les données textuelles extraites du Web ou des médias sociaux. CleanText permet aux développeurs de créer une représentation textuelle normalisée. CleanText utilise ftfy , unidecode et diverses autres règles codées en dur, y compris RegEx, pour convertir un texte d'entrée corrompu ou sale en un texte propre, qui peut être traité ultérieurement pour former un modèle NLP.

# %% [markdown]
# ###**Installation:**
# + La bibliothèque CleanText peut être installée à partir de PyPl à l'aide de la commande suivante :

# %%
# !pip install clean-text
# !pip install Unidecode

# %%
from cleantext import clean

text = """
Zürich has a famous website https://www.zuerich.com/
WHICH ACCEPTS 40,000 € and adding a random string, :
abc123def456ghi789zero0 for this demo. Also remove punctions ,.
my phone number is 9876543210 and mail me at satkr7@gmail.com.'
     """

clean_text = clean(text,
      fix_unicode=True,
      to_ascii=True,
      lower=True,
      no_line_breaks=True,
      no_urls=True,
      no_numbers=True,
      no_digits=True,
      no_currency_symbols=True,
      no_punct=True,
      replace_with_punct="",
      replace_with_url="<URL>",
      replace_with_number="<NUMBER>",
      replace_with_digit="",
      replace_with_currency_symbol="<CUR>",
      lang='en')

print(clean_text)
# Out:
# zurich has a famous website <url> which accepts <number> <cur> and adding a random string abcdefghizero for this demo also remove punctions my phone number is <number> and mail me at satkrgmailcom
