# %%
# !pip install git+https://github.com/adamerose/pandasgui.git

# !pip install pandasgui

# %%
from pandasgui import show
from pandasgui.datasets import pokemon, titanic, all_datasets
show(pokemon, titanic)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-fcf135ab80ef> in <cell line: 1>()
# ----> 1 from pandasgui import show
#       2 from pandasgui.datasets import pokemon, titanic, all_datasets
#       3 show(pokemon, titanic)
#
# /usr/local/lib/python3.10/dist-packages/pandasgui/__init__.py in <module>
#      13
#      14 # Imports
# ---> 15 from pandasgui.gui import show
#      16
#      17 __all__ = ["show", "__version__"]
#
# /usr/local/lib/python3.10/dist-packages/pandasgui/gui.py in <module>
#      15 from pandasgui.widgets.find_toolbar import FindToolbar
#      16 from pandasgui.widgets.json_viewer import JsonViewer
# ---> 17 from pandasgui.widgets.navigator import Navigator
#      18 from pandasgui.widgets.figure_viewer import FigureViewer
#      19 from pandasgui.widgets.settings_editor import SettingsEditor
#
# /usr/local/lib/python3.10/dist-packages/pandasgui/widgets/navigator.py in <module>
#      22         return win32api.GetKeyState(0x01) not in [0, 1]
#      23 else:
# ---> 24     from pynput import mouse
#      25
#      26
#
# /usr/local/lib/python3.10/dist-packages/pynput/__init__.py in <module>
#      38
#      39
# ---> 40 from . import keyboard
#      41 from . import mouse
#
# /usr/local/lib/python3.10/dist-packages/pynput/keyboard/__init__.py in <module>
#      29
#      30
# ---> 31 backend = backend(__name__)
#      32 KeyCode = backend.KeyCode
#      33 Key = backend.Key
#
# /usr/local/lib/python3.10/dist-packages/pynput/_util/__init__.py in backend(package)
#      74                 resolutions.append(RESOLUTIONS[module])
#      75
# ---> 76     raise ImportError('this platform is not supported: {}'.format(
#      77         '; '.join(str(e) for e in errors)) + ('\n\n'
#      78             'Try one of the following resolutions:\n\n'
#
# ImportError: this platform is not supported: ('failed to acquire X connection: Bad display name ""', DisplayNameError(''))
#
# Try one of the following resolutions:
#
#  * Please make sure that you have an X server running, and that the DISPLAY environment variable is set correctly
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
show(**all_datasets)
