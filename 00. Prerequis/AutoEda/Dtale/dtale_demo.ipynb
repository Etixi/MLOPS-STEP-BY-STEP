# %%
# !pip install dtale

# %%
import pandas as pd
import dtale
import dtale.app as dtale_app

dtale_app.USE_COLAB = True

# %%
print(f"{dtale.__version__}")
# Out:
# 3.10.0

# %%
dataset = pd.read_csv("/content/datamart_rfm_scores_named_segment.csv")
dataset.head()
# Out:
#    CustomerID  Recency  Frequency  MonetaryValue  R  F  M  RFM_Segment  \
# 0       12747        3         25         948.70  4  4  4          444
# 1       12748        1        888        7046.16  4  4  4          444
# 2       12749        4         37         813.45  4  4  4          444
# 3       12820        4         17         268.02  4  3  3          433
# 4       12822       71          9         146.15  2  2  3          223
#
#    RFM_Score RFM_Level
# 0       12.0       Top
# 1       12.0       Top
# 2       12.0       Top
# 3       10.0       Top
# 4        7.0    Middle

# %%
dataset.tail()
# Out:
#       CustomerID  Recency  Frequency  MonetaryValue  R  F  M  RFM_Segment  \
# 3638       18280      278          2          38.70  1  1  1          111
# 3639       18281      181          2          31.80  1  1  1          111
# 3640       18282        8          2          30.70  4  1  1          411
# 3641       18283        4        152         432.93  4  4  4          444
# 3642       18287       43         15         395.76  3  3  4          334
#
#       RFM_Score RFM_Level
# 3638        3.0       Low
# 3639        3.0       Low
# 3640        6.0    Middle
# 3641       12.0       Top
# 3642       10.0       Top

# %%
dataset.shape
# Out:
# (3643, 10)

# %% [markdown]
# ### Méthode 1

# %%
dtale.show(dataset)
# Out:
# https://11vxfhr6hia-496ff2e9c6d22116-40000-colab.googleusercontent.com/dtale/main/1

# %% [markdown]
# ### Méthode 2

# %%
dtale.show(open_browser=True)
# Out:
# https://11vxfhr6hia-496ff2e9c6d22116-40000-colab.googleusercontent.com/dtale/main/1

# %% [markdown]
# ![image.png](data:image/png;base64,...)
