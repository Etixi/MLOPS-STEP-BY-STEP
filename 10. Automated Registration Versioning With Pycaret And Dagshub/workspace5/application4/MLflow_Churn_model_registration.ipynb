# %%
# !pip install mlflow==2

# %%
# !pip install pycaret

# %%
import mlflow
mlflow.start_run()
mlflow.log_param("parameter name", "value")
mlflow.log_metric("metric name", 1)
mlflow.end_run()

# %%
# set env variables
import os

os.environ['MLFLOW_TRACKING_USERNAME'] = 'Etixi'
os.environ['MLFLOW_TRACKING_PASSWORD'] = '7105226e046f52c659cc559f1014f42e5ae1e461'
os.environ['MLFLOW_TRACKING_URI'] = 'https://dagshub.com/Etixi/customer_churn.mlflow'
os.environ["PYCARET_CUSTOM_LOGGING_LEVEL"] = "CRITICAL"

# set mlflow tracking uri
import mlflow
mlflow.set_tracking_uri("https://dagshub.com/Etixi/customer_churn.mlflow")

# %%
import pycaret
import mlflow
#mlflow.set_tracking_uri("http://localhost:5000")

# %%
import pycaret
pycaret.__version__
# Out:
# '3.0.4'

# %%
import pandas as pd
data = pd.read_csv('final_data.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# initialize setup
from pycaret.classification import *
s = setup(data, target = 'Churn', session_id = 123,
          ignore_features = ['customerID'],
          log_experiment = True,
          experiment_name = 'churn1')
# Out:
# <style type="text/css">
# #T_03dfd_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_03dfd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03dfd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_03dfd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03dfd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03dfd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_03dfd_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_03dfd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03dfd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_03dfd_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_03dfd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_6575c th {
#   text-align: left;
# }
# ...

# %%
print(best_model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator='deprecated',
#                    estimator=None, learning_rate=1.0, n_estimators=50,
#                    random_state=123)

# %%
plot_model(best_model, plot = 'auc')

# %%
plot_model(best_model, plot = 'confusion_matrix')

# %%
plot_model(best_model, plot = 'boundary')

# %%
plot_model(best_model, plot = 'feature')

# %%
# save pipeline
save_model(best_model, 'model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['SeniorCitizen', 'tenure',
#                                               'MonthlyCharges', 'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None...
#                                                                      'TechSupport',
#                                                                      'StreamingTV',
# ...
