# %%
# !pip install datatile

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpg = sns.load_dataset('mpg')

# %%
from datatile.summary.df import DataFrameSummary

dfs = DataFrameSummary(mpg)

# %%
dfs

# %%
dfs.summary()
# Out:
#                     mpg cylinders displacement  horsepower       weight  \
# count             398.0     398.0        398.0       392.0        398.0
# mean          23.514573  5.454774   193.425879  104.469388  2970.424623
# std            7.815984  1.701004   104.269838    38.49116   846.841774
# min                 9.0       3.0         68.0        46.0       1613.0
# 25%                17.5       4.0       104.25        75.0      2223.75
# 50%                23.0       4.0        148.5        93.5       2803.5
# 75%                29.0       8.0        262.0       126.0       3608.0
# max                46.6       8.0        455.0       230.0       5140.0
# counts              398       398          398         392          398
# uniques             129         5           82          93          351
# missing               0         0            0           6            0
# missing_perc         0%        0%           0%       1.51%           0%
# ...

# %%
dfs.columns_types
# Out:
# numeric        7
# categorical    2
# Name: types, dtype: int64

# %%
dfs.columns_stats()
# Out:
#                   mpg cylinders displacement horsepower   weight acceleration  \
# counts            398       398          398        392      398          398
# uniques           129         5           82         93      351           95
# missing             0         0            0          6        0            0
# missing_perc       0%        0%           0%      1.51%       0%           0%
# types         numeric   numeric      numeric    numeric  numeric      numeric
#
#              model_year       origin         name
# counts              398          398          398
# uniques              13            3          305
# missing               0            0            0
# missing_perc         0%           0%           0%
# types           numeric  categorical  categorical
