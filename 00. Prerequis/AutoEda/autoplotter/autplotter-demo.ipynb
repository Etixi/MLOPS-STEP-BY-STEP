# %%
# !pip install autoplotter
# !pip install -v https://github.com/pallets/werkzeug/archive/refs/tags/2.0.3.tar.gz

# %%
# Installed packages
import pandas as pd


# Our package
from autoplotter import*
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-f89c815bd3d5> in <cell line: 6>()
#       4
#       5 # Our package
# ----> 6 from autoplotter import*
#
# /usr/local/lib/python3.10/dist-packages/autoplotter/__init__.py in <module>
# ----> 1 from .app import run_app
#       2
#       3 __ALL__ = ['run_app']
#
# /usr/local/lib/python3.10/dist-packages/autoplotter/app.py in <module>
# ----> 1 import dash_bootstrap_components as dbc
#       2 import dash_html_components as  html
#       3 import dash_core_components as dcc
#       4 from .side_navbar import _navbar
#       5 from .jupyter_dash import JupyterDash
#
# /usr/local/lib/python3.10/dist-packages/dash_bootstrap_components/__init__.py in <module>
#       2 import os
#       3
# ----> 4 from dash_bootstrap_components import _components, icons, themes
#       5 from dash_bootstrap_components._components import *  # noqa
#       6 from dash_bootstrap_components._components import Table
#
# /usr/local/lib/python3.10/dist-packages/dash_bootstrap_components/_components/__init__.py in <module>
# ----> 1 from .Accordion import Accordion
#       2 from .AccordionItem import AccordionItem
#       3 from .Alert import Alert
#       4 from .Badge import Badge
#       5 from .Breadcrumb import Breadcrumb
#
# /usr/local/lib/python3.10/dist-packages/dash_bootstrap_components/_components/Accordion.py in <module>
#       1 # AUTO GENERATED FILE - DO NOT EDIT
#       2
# ----> 3 from dash.development.base_component import Component, _explicitize_args
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/dash/__init__.py in <module>
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dependencies import (  # noqa: F401,E402
#       6     Input,  # noqa: F401,E402
#       7     Output,  # noqa: F401,E402,
#
# /usr/local/lib/python3.10/dist-packages/dash/dependencies.py in <module>
#       2 from dash.development.base_component import Component
#       3
# ----> 4 from ._validate import validate_callback
#       5 from ._grouping import flatten_grouping, make_grouping_by_index
#       6
#
# /usr/local/lib/python3.10/dist-packages/dash/_validate.py in <module>
#       3 from textwrap import dedent
#       4 from keyword import iskeyword
# ----> 5 import flask
#       6
#       7 from ._grouping import grouping_len, map_grouping
#
# /usr/local/lib/python3.10/dist-packages/flask/__init__.py in <module>
#       2 from markupsafe import Markup
#       3
# ----> 4 from . import json as json
#       5 from .app import Flask as Flask
#       6 from .app import Request as Request
#
# /usr/local/lib/python3.10/dist-packages/flask/json/__init__.py in <module>
#       6 from jinja2.utils import htmlsafe_json_dumps as _jinja_htmlsafe_dumps
#       7
# ----> 8 from ..globals import current_app
#       9 from .provider import _default
#      10
#
# /usr/local/lib/python3.10/dist-packages/flask/globals.py in <module>
#      54 _cv_app: ContextVar["AppContext"] = ContextVar("flask.app_ctx")
#      55 __app_ctx_stack = _FakeStack("app", _cv_app)
# ---> 56 app_ctx: "AppContext" = LocalProxy(  # type: ignore[assignment]
#      57     _cv_app, unbound_message=_no_app_msg
#      58 )
#
# TypeError: LocalProxy.__init__() got an unexpected keyword argument 'unbound_message'
